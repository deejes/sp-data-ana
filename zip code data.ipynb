# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import time;  from datetime import datetime
import math
plt.rcParams["figure.figsize"] = (15,10)

# %%
# zipcode = pd.read_csv('15zpallagi.csv') # read the csv
zipcode = pd.read_excel('zip_data.xlsx') # read the csv

def to_string(row):
    return str(row)

zipcode['Zip'] = zipcode.Zip.apply(to_string)
zipcode.set_index("Zip", inplace=True)

# %%
zipcode.shape
# Out:
# (32634, 3)

# %%
zipcode[zipcode.Pop>9000].sort_values("Median").tail(150).plot.bar()

# %%
# TODO - Investigate 4 digit zip codes - possibly add 0 to the front 
# Do these include airports etc? Which should presumably be excluded

# %%
zipcode.sort_values("Median")[["Pop"]].tail(300).plot.bar()

# %%
a = "a"
