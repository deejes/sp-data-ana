# %%
import pandas as pd

# %%
df1 = pd.read_excel("Analytics_All_Web_Site_Data_AdWords_Search_Queries_20170615-20180302.xlsx",sheet_name="Dataset1")

# %%
df2 = pd.read_excel("Analytics_All_Web_Site_Data_AdWords_Search_Queries_20170615-20180302_(1).xlsx",sheet_name="Dataset1")

# %%
# remove last row of summary statistics
df1 = df1.iloc[:-1]
df2 = df2.iloc[:-1]

# %%
df1.head()
# Out:
#    Search Query Device Category  Clicks         Cost       CPC  Users  \
# 0   lovers lane          mobile   23784  4661.140473  0.195978  16892
# 1  adam and eve          mobile   11623  4136.570907  0.355895   9909
# 2    cock rings          mobile   11432  3908.717332  0.341910   9860
# 3     lions den          mobile   11255  1430.801782  0.127126   8788
# 4      sex toys          mobile   10769  6282.888300  0.583424   8950
#
#    Sessions  Bounce Rate  Pages / Session  Ecommerce Conversion Rate  \
# 0     23924     0.338739         6.585437                   0.012373
# 1     12046     0.220156         8.804831                   0.016354
# 2     11807     0.419328         4.576353                   0.014314
# 3     12322     0.334280         6.884110                   0.008034
# 4     10897     0.178673         9.120308                   0.012297
#
#    Transactions       Revenue
# 0           296  14427.932060
# 1           197  16738.700462
# 2           169   5351.590941
# ...

# %%
df2.head()
# Out:
#                 Search Query Device Category  Clicks       Cost       CPC  \
# 0  women's favorite sex toys          mobile      34  11.993959  0.352764
# 1       worlds best vibrator          mobile      34  10.815133  0.318092
# 2              1 rated dildo          mobile      33   5.387787  0.163266
# 3                 8 vibrator          mobile      33   7.049220  0.213613
# 4        adam & eve sex toys          mobile      33   9.794539  0.296804
#
#    Users  Sessions  Bounce Rate  Pages / Session  Ecommerce Conversion Rate  \
# 0     21        21     1.000000         1.000000                        0.0
# 1     14        14     1.000000         1.000000                        0.0
# 2     28        35     0.400000         3.628571                        0.0
# 3     21        28     0.000000         7.821429                        0.0
# 4     21        21     0.333333         9.761905                        0.0
#
#    Transactions  Revenue
# 0             0      0.0
# ...

# %%
df1.head().append(df2.head()).reset_index().drop('index')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-fec8abada58c> in <module>()
# ----> 1 df1.head().append(df2.head()).reset_index().drop('index')
#
# ~/programming/data_env/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~/programming/data_env/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
# ...
