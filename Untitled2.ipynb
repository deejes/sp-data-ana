# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import time;  from datetime import datetime
import math
plt.rcParams["figure.figsize"] = (15,10)

# %%
geographic = pd.read_csv('Geographic.csv') # read the mobile

# %%
geographic[geographic["Country/Territory"] == "United States"]
# Out:
#       Country/Territory                  Region  \
# 0         United States                  Alaska
# 1         United States              California
# 2         United States              California
# 3         United States              California
# 5         United States                Arkansas
# 6         United States                 Arizona
# 7         United States                Arkansas
# 8         United States              California
# 9         United States                 Alabama
# 10        United States                 Alabama
# 11        United States              California
# 12        United States              California
# 13        United States              California
# 14        United States                Arkansas
# 15        United States              California
# 16        United States                 Alabama
# 17        United States              California
# 19        United States                Arkansas
# ...

# %%
location_criteria = pd.read_csv("adwords_api_location_criteria.csv")

# %%
us_location_criteria = location_criteria[location_criteria["Country Code"]=="US"]

# %%
us_location_criteria['Target Type'].unique()
# Out:
# array(['City', 'Neighborhood', 'Municipality', 'University', 'County',
#        'Borough', 'Airport', 'State', 'Country', 'Postal Code',
#        'Congressional District', 'National Park', 'Region', 'City Region',
#        'District'], dtype=object)

# %%
us_location_criteria[us_location_criteria['Target Type']== "National Park"]
# Out:
#        Criteria ID                                            Name  \
# 94023      9069331                            Acadia National Park
# 94025      9069333                            Arches National Park
# 94026      9069334                          Badlands National Park
# 94027      9069335                          Big Bend National Park
# 94028      9069336                          Biscayne National Park
# 94029      9069337      Black Canyon of the Gunnison National Park
# 94030      9069338                      Bryce Canyon National Park
# 94031      9069339                       Canyonlands National Park
# 94032      9069340                      Capitol Reef National Park
# 94033      9069341                  Carlsbad Caverns National Park
# 94034      9069342                   Channel Islands National Park
# 94035      9069343                          Congaree National Park
# 94036      9069344                       Crater Lake National Park
# ...
