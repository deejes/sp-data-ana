# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import time;  from datetime import datetime
import math
plt.rcParams["figure.figsize"] = (15,10)

# %%
nyc = pd.read_csv('gapi_city_data-export-2017-11-30.csv') # read the gapi database

# %%
nyc.head()
# Out:
#       City   Date Hour          User Type Device Category  Sessions  Bounces  \
# 0  1024931  2017070916        New Visitor          mobile         1        0
# 1  1024931  2017070917  Returning Visitor          mobile         1        0
# 2  1024931  2017070919  Returning Visitor          mobile         1        0
# 3  1024931  2017070920  Returning Visitor          mobile         0        0
# 4  1024931  2017071014        New Visitor          mobile         2        0
#
#    Users  New Users  Transactions  Transaction Revenue  Revenue Per User  \
# 0      1        NaN             0                  0.0               0.0
# 1      1        NaN             0                  0.0               0.0
# 2      1        NaN             0                  0.0               0.0
# 3      1        NaN             0                  0.0               0.0
# 4      2        NaN             0                  0.0               0.0
#
#    Page Value  Organic Searches
# 0         0.0                 0
# 1         0.0                 0
# 2         0.0                 0
# 3         0.0                 0
# 4         0.0                 0
